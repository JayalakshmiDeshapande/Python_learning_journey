# %% [markdown]
# <a href="https://colab.research.google.com/github/JayalakshmiDeshapande/Python_learning_journey/blob/main/python_learning_journey_day02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first_name="shubansh"
last_name="shukla"
full_name=first_name+" "+last_name
print(full_name)
print(full_name*5)
print(full_name.upper())
print(full_name.lower())
print(full_name.strip()*2)
print(full_name.replace("shubansh shukla","Sunitha William"))
#indenxing
country="India"
print(len(country))
print(country[4])
print(country[0:])
print(country[:5])
print(country[0:5:2])#start:end:strip
print(country[0:4])
print(country[0:5:3])#start:end:strip

#escape sequences
"""\n is next line and \t is tab"""
#operators
a=10
b=20
a+=b # This performs the addition and assignment a=a+b
print(a) # This prints the updated value of a
a*=b #a=a*b
print(a)
#comparison operator
a=20
b=10
print(a==b)
print(a>=b)
print(a<=b)
print(a!=b)
#logical operator and,or,not
print(a>b and a<b) #true if both are true
print(a>b or a<b) #true if any one of is true
#membership operator
s="care"
print("c" in s)
print("c" not in s )
#using logical operators
#and operator
'''num1=float(input("enter the first number"))
num2=float(input("enter the second number"))
if(num1>10 and num2>10):
  print("both numbers are greater than 10")
else:
  print("both numbers are not greater than 10") '''

#or operator
'''num1=float(input("enter the first number"))
num2=float(input("enter the second number"))
if(num1>10 or num2<5):
  print("atleast one num is less than 5")'''
#not operator
'''num1=float(input("enter the first number"))
num2=float(input("enter the second number"))
print(not(num1>num2))'''
#comparison operator
'''age=int(input("enter your age"))
if(age>=18):
  print("you are eligible to vote")
if(age<18):
  print("you are not eligible to vote")'''
#membership operator
country=input("enter your country")
if("In" in country):
  print("you are from India!!")
else:
  print("you are not from India!!")
# Out:
# shubansh shukla
# shubansh shuklashubansh shuklashubansh shuklashubansh shuklashubansh shukla
# SHUBANSH SHUKLA
# shubansh shukla
# shubansh shuklashubansh shukla
# Sunitha William
# 5
# a
# India
# India
# Ida
# Indi
# Ii
# 30
# 600
# False
# True
# False
# True
# False
# True
# True
# False
# enter your countryIndia
# you are from India
