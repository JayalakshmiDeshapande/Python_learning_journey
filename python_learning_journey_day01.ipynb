# %% [markdown]
# <a href="https://colab.research.google.com/github/JayalakshmiDeshapande/Python_learning_journey/blob/main/python_learning_journey_day01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#learning from engineering in kannada
#variables usage
a=10
b=5
print(a)
#finding the type of the data
name= "Shreya"
age= 22
print(type(age))
#arithmetic operator
a=2
b=3
print(a+b)
print(abs(a-b)) #if we dont  want -ve values, we can use abs
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
#usage of input and output function
name=(input("enter the name of the student: "))
science_marks=int(input("enter the marks in science: "))
mathematics_marks=int(input("enter the marks in mathematics: "))
total_marks=science_marks+mathematics_marks
print(name+" scored ",total_marks "in science and mathematics")
# Out:
# 10
# <class 'int'>
# 5
# 1
# 6
# 0.6666666666666666
# 0
# 2
# 8
# enter the name of the student: shreya
# enter the marks in science: 98
# enter the marks in mathematics: 91
# shreya scored  189 in science and mathematics
