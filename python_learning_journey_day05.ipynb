# %% [markdown]
# <a href="https://colab.research.google.com/github/JayalakshmiDeshapande/Python_learning_journey/blob/main/python_learning_journey_day05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionaries, they are unordered and mutable, consists of key and values
birthday={
    "jayu":"11-10-2007",
    "shri":"21-12-2004",
}
print(birthday)
print(type(birthday))
print(birthday["jayu"])#accessing the values
#print dictionary using dict keyword
my_dict=dict(name="Ram",age=24,city="kathmandu")
print(my_dict)
print(birthday.get("sudeep","not found!!"))
'''another way to access .. use of get function is, the program will not crash even if the dictionary is not having a given value'''
birthday["sudeep"]="2-9-1972" #adds during run time
print(birthday)
birthday["sudeep"]="2-9-1973"#updating
birthday["agastya"]="10-10-2018"
print(birthday)
del birthday["sudeep"] #we can't access later onwards
print(birthday)
x=birthday.pop("shri")
print(birthday)
print(x) #we can use evn though its already deleted in dictionary.
print(birthday.keys())
print(birthday.values())
print(birthday.items())
item1={
    "name":"panipuri",
    "price":"50",
}
itme2={
    "name":"masalapuri",
    "price":"50",
}
items=[item1,itme2]
print(items)
print(f"Total weight:{int(item1['price'])+int(itme2['price'])} rupees")

student_grades={
    ("kannada,first_languages"):"90",
    ("english,second_languages"):"80",
}
print(student_grades)
# Out:
# {'jayu': '11-10-2007', 'shri': '21-12-2004'}
# <class 'dict'>
# 11-10-2007
# {'name': 'Ram', 'age': 24, 'city': 'kathmandu'}
# not found!!
# {'jayu': '11-10-2007', 'shri': '21-12-2004', 'sudeep': '2-9-1972'}
# {'jayu': '11-10-2007', 'shri': '21-12-2004', 'sudeep': '2-9-1973', 'agastya': '10-10-2018'}
# {'jayu': '11-10-2007', 'shri': '21-12-2004', 'agastya': '10-10-2018'}
# {'jayu': '11-10-2007', 'agastya': '10-10-2018'}
# 21-12-2004
# dict_keys(['jayu', 'agastya'])
# dict_values(['11-10-2007', '10-10-2018'])
# dict_items([('jayu', '11-10-2007'), ('agastya', '10-10-2018')])
# [{'name': 'panipuri', 'price': '50'}, {'name': 'masalapuri', 'price': '50'}]
# Total weight:100 rupees
# {'kannada,first_languages': '90', 'english,second_languages': '80'}
