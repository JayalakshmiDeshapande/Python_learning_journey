# %% [markdown]
# <a href="https://colab.research.google.com/github/JayalakshmiDeshapande/Python_learning_journey/blob/main/python_learning_journey_day03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lists in python
''' it is ordered , mutable , allow duplicate elements, can hold integers, strings,and other lists too
cities=["bengaluru" , "bijapur" , "mysore"]
print(cities[1])
pop-removes last and first element from the list
cities.pop()
cities.pop(0)
print(cities)
#append-adds last element to the list
cities.append("mangalore")
print(cities)
cities.remove("bijapur")
print(cities)
list=[1 , "jayu", 2, 3]'''
# insert- used to add middle of the list
'''print(list.insert(1,"dakshina karartaka"))
list.clear() #clears the statement
print(list)
list[0]="100" #if we want to replace
print(list)'''
'''foods=["panipuri" , "vadapav" , "bhelpuri" , "panipuri"]
print(len(foods))
print(foods.count("panipuri"))
print(foods.index("panipuri"))
foods.reverse()
print(foods)
foods.sort()
print(foods)'''
#nested list- eg is matrix
m=[[1,2],[3,4]]
print(m)
print(m[0])
print(m[0][1])
# Out:
# [[1, 2], [3, 4]]
# [1, 2]
# 2
